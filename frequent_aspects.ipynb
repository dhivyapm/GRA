# %%
import pandas as pd
from textblob import TextBlob, Word
import nltk
data = pd.read_csv('imdb_dataset.csv',sep=',')

# %%
data.head(4)
data1 = data.iloc[:10000]

# %%
#Verb + Noun
def aspect_VN(txt):
    
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    for line in sentList:
        new_txt_list = nltk.word_tokenize(line)
        taggedList = nltk.pos_tag(new_txt_list)

    #print(taggedList)
    categoryList = []

    for i in range(0,len(taggedList)-1):
         if((taggedList[i][1]=="VB" or taggedList[i][1]=="VBP" or taggedList[i][1]=="VBG" or taggedList[i][1]=="VBN" or taggedList[i][1]=="VBD") and 
           (taggedList[i+1][1]=="NN" or taggedList[i+1][1]=="NNS" or taggedList[i+1][1]=="NNP" or taggedList[i+1][1]=="NNPS")):

            categoryList.append([taggedList[i][0]+" " +taggedList[i+1][0]])

    return categoryList

# %%
categoryList_VN= [aspect_VN(data['unique_sent'][unt]) for unt in range(0,10000)]

# %%
flat_VN = list(nested_list_flatten(categoryList_VN))

# %%
freq_feature_VN = freq_aspects(flat_VN,50)
freq_feature_VN
# Out:
# ['take place',
#  'seen movie',
#  'see movie',
#  'recommend anyone',
#  'want see',
#  'make sense',
#  'made tv',
#  'supporting cast']

# %%
#Adjective + Noun
def aspect_AN(txt):
    
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    for line in sentList:
        new_txt_list = nltk.word_tokenize(line)
        taggedList = nltk.pos_tag(new_txt_list)

    #print(taggedList)
    categoryList = []

    for i in range(0,len(taggedList)-1):
        if((taggedList[i][1]=="JJ") and (taggedList[i+1][1]=="NN" or taggedList[i+1][1]=="NNS" or taggedList[i+1][1]=="NNP" or taggedList[i+1][1]=="NNPS")):

            categoryList.append([taggedList[i][0]+" " +taggedList[i+1][0]])
        
    return categoryList

# %%
categoryList = [aspect_AN(data1['unique_sent'][unt]) for unt in range(0,10000)]

# %%
categoryList
# Out:
# [[['review list'],
#   ['american tv'],
#   ['poor watch'],
#   ['dumb fool'],
#   ['standard measure'],
#   ['similar work'],
#   ['good character'],
#   ['big production'],
#   ['sensitive cinematography'],
#   ['top notch'],
#   ['cinematic direction'],
#   ['memorable episode'],
#   ['perfect way'],
#   ['human mean'],
#   ['wa kid'],
#   ['classic amount'],
#   ['ultimate formula'],
#   ['detective hawaii'],
#   ['fine baby'],
#   ['lovely book'],
#   ['thoughtful line'],
#   ['vietnam war'],
#   ['rainy night'],
#   ['shinny day'],
#   ['main brain'],
#   ['tc heart'],
#   ['distinct relationship'],
#   ['english gentleman'],
#   ['severe father'],
#   ['resemble learn'],
#   ['previous symptom'],
#   ['tom selleck'],
#   ['serious instance'],
#   ['strong actor'],
#   ['deep feed'],
#   ['marked advertisement'],
#   ['present something'],
#   ['pastime word'],
#   ['heaven place'],
#   ['ecstasy get'],
#   ['certain mode'],
#   ['equal opus'],
#   ['watching sentiment'],
#   ['magical element'],
#   ['important home']],
#  [['former intern'],
#   ['scary look'],
#   ['awesome attraction'],
#   ['many house'],
#   ['comedic approach'],
#   ['good mix'],
#   ['unique family'],
#   ['combine horror'],
#   ['full people'],
#   ['clapped end'],
#   ['nice beginning'],
#   ['organ music'],
#   ['great job'],
#   ['special effect'],
#   ['bored time']],
#  [['horrible idea'],
#   ['combo stiller'],
#   ['script scene'],
#   ['new car'],
#   ['different type'],
#   ['hard edge'],
#   ['con artist'],
#   ['bad gay'],
#   ['spice edginess'],
#   ['able use'],
#   ['much sequel']],
#  [['awful question'],
#   ['wa commentary'],
#   ['bad watch'],
#   ['hard conspiracy'],
#   ['utter lack'],
#   ['decided conclusion'],
#   ['natural desire']],
#  [['low budget'],
#   ['martial art'],
#   ['potential lew'],
#   ['whole thing'],
#   ['real think'],
#   ['screen character'],
#   ['fart fight'],
#   ['worth rent']],
#  [['big fan'],
#   ['first scene'],
#   ['x heaven'],
#   ['thought wa'],
#   ['allow thing'],
#   ['script stunk'],
#   ['bad book'],
#   ['know deal']],
#  [['subversive homosexuality'],
#   ['choppy junk'],
#   ['good laugh'],
#   ['eric care'],
#   ['snl message'],
#   ['third season']],
#  [['describe movie'],
#   ['hundred time'],
#   ['past andrew'],
#   ['huge crush'],
#   ['mary fall'],
#   ['disappointed end'],
#   ['great job'],
#   ['black beauty'],
#   ['surprised ha']],
#  [['crazy film'],
#   ['come watch'],
#   ['due joint'],
#   ['forgotten year'],
#   ['jewish woman'],
#   ['alien nymphomaniac'],
#   ['last week'],
#   ['heavy metal'],
#   ['wept joy'],
#   ['ebay buy'],
#   ['post haste'],
#   ['relax charlie']],
#  [['wish life'],
#   ['irrepressible joy'],
#   ['miserable weekend'],
#   ['joyous romp'],
#   ['episode tv'],
#   ['common practice']],
#  [['special effect'],
#   ['classic hell'],
#   ['lead patent'],
#   ['straight film'],
#   ['eager wiseacre'],
#   ['naval cadet'],
#   ['hellcat fighter'],
#   ['many friend'],
#   ['enable plane'],
#   ['open complication'],
#   ['unwelcome chance'],
#   ['redeem end'],
#   ['cheap opposite'],
#   ['visual sound'],
#   ['tactic war'],
#   ['early twenty'],
#   ['ancient world'],
#   ['united state'],
#   ['le pearl'],
#   ['whole lot'],
#   ['good bearing']],
#  [['wonderful fran'],
#   ['spectacular malibu'],
#   ['annoying thick'],
#   ['accent appearance'],
#   ['black hair'],
#   ['gracious host'],
#   ['fan actor'],
#   ['daniel davis'],
#   ['nile butler'],
#   ['noticeable star'],
#   ['memorable moment'],
#   ['real treat'],
#   ['friendship series']],
#  [['dial intelligence'],
#   ['dumb teen'],
#   ['cheesy action'],
#   ['gal hack'],
#   ['real life'],
#   ['russian peace'],
#   ['explode oil'],
#   ['good ol'],
#   ['u death'],
#   ['white house'],
#   ['big target'],
#   ['rest involves'],
#   ['slow motion'],
#   ['nerd turn'],
#   ['plot destruction'],
#   ['free world'],
#   ['attractive lady'],
#   ['social freak'],
#   ['radical commit'],
#   ['superman kill'],
#   ['much scratch'],
#   ['ludicrous movie'],
#   ['merit script'],
#   ['till end'],
#   ['little waste'],
#   ['funny monologue'],
#   ['main character'],
#   ['unhilarious thing'],
#   ['plus scene']],
#  [['obvious sense'],
#   ['straight afterwards'],
#   ['golden child'],
#   ['huge hit'],
#   ['distinguished gentleman'],
#   ['nonsensical set'],
#   ['indulgent turn'],
#   ['landis director'],
#   ['documentary alledges'],
#   ['second everything'],
#   ['surprising misfire'],
#   ['previous star'],
#   ['stuck playing'],
#   ['phoned performance'],
#   ['comedy action'],
#   ['final huh'],
#   ['compensate lack'],
#   ['homosexual coffee'],
#   ['become arm'],
#   ['good edge'],
#   ['ludicrousness situation'],
#   ['entire fee'],
#   ['successful series'],
#   ['multiple character'],
#   ['dave cue']],
#  [['horror film'],
#   ['weird jennifer'],
#   ['leigh lead'],
#   ['good playing'],
#   ['disturbed people'],
#   ['white female'],
#   ['fascinating time'],
#   ['audio sound'],
#   ['nightclub house'],
#   ['interior story'],
#   ['bad taste'],
#   ['sordid spot'],
#   ['social worker'],
#   ['attractive haunting'],
#   ['bizarre tale']],
#  [['national security'],
#   ['old school'],
#   ['new talent'],
#   ['fantastic chilling'],
#   ['broad scenery'],
#   ['encompassing sort'],
#   ['liberty family'],
#   ['escabedo scumbag'],
#   ['serious cali'],
#   ['closed door'],
#   ['white house'],
#   ['watch government'],
#   ['novel movie'],
#   ['compelling performance'],
#   ['retained saw'],
#   ['present danger'],
#   ['performed driving'],
#   ['beautiful drug'],
#   ['special effect'],
#   ['yes thats'],
#   ['top end'],
#   ['salary work']],
#  [['whole production'],
#   ['live presentation'],
#   ['fluff note'],
#   ['special effect'],
#   ['existent fact'],
#   ['real time'],
#   ['modern story'],
#   ['difficult question'],
#   ['original version']],
#  [['human drama'],
#   ['shoe cope'],
#   ['sudden life'],
#   ['parent family'],
#   ['fine performance']],
#  [['sad movie'],
#   ['classic tale'],
#   ['dark side'],
#   ['good writing'],
#   ['mean point'],
#   ['teeth manage'],
#   ['horrible death']],
#  [['enough drama'], ['wa action'], ['patrick swayze'], ['neeson ben']],
#  [['grand prix'],
#   ['piece art'],
#   ['simple word'],
#   ['first time'],
#   ['child way'],
#   ['beautiful mountain'],
#   ['alive spite'],
#   ['small number'],
#   ['technological marvel'],
#   ['monstrous car'],
#   ['stomach story'],
#   ['whole world']],
#  [['second time'],
#   ['big screen'],
#   ['original dvd'],
#   ['oberoi talent'],
#   ['increase fan'],
#   ['rahman anil'],
#   ['last year'],
#   ['magnificent shah'],
#   ['brief appearance'],
#   ['great pair'],
#   ['lead future'],
#   ['gulzar dialogue'],
#   ['directorial effort']],
#  [['chappan end'],
#   ['surprised promote'],
#   ['start question'],
#   ['understand motivation'],
#   ['realistic chawls'],
#   ['touch smell'],
#   ['much dialogue'],
#   ['common man'],
#   ['divert attention'],
#   ['top notch'],
#   ['leave breathless'],
#   ['colloquial setup']],
#  [['idol thing'],
#   ['much innovator'],
#   ['real tv'],
#   ['non cheesecake'],
#   ['wayfarin stranger'],
#   ['wild seed'],
#   ['adventure feature'],
#   ['kaye movie'],
#   ['popular show']],
#  [['eric robert'],
#   ['complete idiot'],
#   ['clean thing'],
#   ['psycho work'],
#   ['want agree'],
#   ['many time'],
#   ['doe jump'],
#   ['tough escape'],
#   ['dum coffee'],
#   ['terrorist female'],
#   ['good laugh'],
#   ['sure winner']],
#  [['dead time'],
#   ['executive producer'],
#   ['earp meet'],
#   ['aliesn leader'],
#   ['urban legend'],
#   ['elm street'],
#   ['wooden move'],
#   ['public wa'],
#   ['big screen']],
#  [['nice cinematography'],
#   ['little explanation'],
#   ['enough time'],
#   ['wa spent'],
#   ['understandable audience'],
#   ['shot space'],
#   ['main thrust']],
#  [['critic reach'],
#   ['positive review'],
#   ['last film'],
#   ['appeal cruise'],
#   ['logic minority'],
#   ['sympathetic character'],
#   ['characteristic craft'],
#   ['high story'],
#   ['u jaw'],
#   ['dry kubrick']],
#  [['bunch college'],
#   ['much drama'],
#   ['lead character'],
#   ['accidental death'],
#   ['basic moment'],
#   ['piece creature'],
#   ['american mythology'],
#   ['goer story'],
#   ['long time']],
#  [['western type'],
#   ['indian movie'],
#   ['american desi'],
#   ['unclear point'],
#   ['accent choice'],
#   ['realistic action'],
#   ['bad taste'],
#   ['choose watch'],
#   ['pen log']],
#  [['know movie'],
#   ['pumped see'],
#   ['timer tv'],
#   ['speechless farce'],
#   ['live boxing'],
#   ['fantasy recommend']],
#  [['saw movie'],
#   ['predictable villain'],
#   ['next door'],
#   ['young boy'],
#   ['shallow character'],
#   ['new feature'],
#   ['poor production'],
#   ['bart darkness'],
#   ['imdb com'],
#   ['cast telescope'],
#   ['suspicious thing'],
#   ['rear window'],
#   ['cheap ripoff']],
#  [['full comedy'],
#   ['thin martin'],
#   ['short kevin'],
#   ['tuck pendleton'],
#   ['human body'],
#   ['steven spielberg'],
#   ['natural talent'],
#   ['great success'],
#   ['incredible story'],
#   ['lt member'],
#   ['secret miniaturization'],
#   ['rival team'],
#   ['stole plan'],
#   ['end jack'],
#   ['strange voice'],
#   ['awesome adventure']],
#  [['nick jolley'],
#   ['cop job'],
#   ['wormhole end'],
#   ['brief moment'],
#   ['horrid piece'],
#   ['avoid kind'],
#   ['else question']],
#  [['lot movie'],
#   ['nice let'],
#   ['wa role'],
#   ['angelina way'],
#   ['believable brother'],
#   ['nut convince'],
#   ['unexpected story'],
#   ['runtime dvd'],
#   ['cinema holland'],
#   ['native language'],
#   ['obvious reason'],
#   ['thin character']],
#  [['migrant worker'],
#   ['eastern europe'],
#   ['convincing performance'],
#   ['logic continuity'],
#   ['many sub'],
#   ['distractive romance'],
#   ['polish doe'],
#   ['help family'],
#   ['disappear scene'],
#   ['tangible end']],
#  [['hilarious deadpan'],
#   ['physical performance'],
#   ['short bit'],
#   ['exhausting watch'],
#   ['entire feature'],
#   ['modern brain'],
#   ['unnecessary joy'],
#   ['multiple point'],
#   ['southern engineer'],
#   ['civil war'],
#   ['gray stop'],
#   ['boring way'],
#   ['comedic stunt'],
#   ['plight eye'],
#   ['frightened rest'],
#   ['due surprise'],
#   ['dvd company'],
#   ['classical piece'],
#   ['plus side'],
#   ['top perfect'],
#   ['enjoyable work'],
#   ['comedian want']],
#  [['give salvation'],
#   ['black woman'],
#   ['believe man'],
#   ['good make'],
#   ['wrong choice'],
#   ['forgive bishop']],
#  [['sorry sound'],
#   ['american gi'],
#   ['high school'],
#   ['forty year'],
#   ['mystery end'],
#   ['italian family'],
#   ['lainie kazan'],
#   ['former beau'],
#   ['inexplicable response'],
#   ['next generation'],
#   ['believable moment'],
#   ['french farce'],
#   ['greek tragedy'],
#   ['terrible cast'],
#   ['emotional life'],
#   ['u impression'],
#   ['insipid cue']],
#  [['good horror'],
#   ['ingredient suspense'],
#   ['insane character'],
#   ['lucky plot'],
#   ['text second'],
#   ['minute boredom'],
#   ['hear scream'],
#   ['clean end'],
#   ['last scene'],
#   ['complete waste']],
#  [['understand point'],
#   ['hopper reputation'],
#   ['mean cop'],
#   ['overall mention'],
#   ['actor way'],
#   ['want test'],
#   ['bad dennie']],
#  [['material fun'],
#   ['old story'],
#   ['human hollywood'],
#   ['macho pistol'],
#   ['right cheek'],
#   ['inside x'],
#   ['skinner end'],
#   ['table sit'],
#   ['enjoyable time'],
#   ['rough language']],
#  [['bad movie'],
#   ['horrible beast'],
#   ['much jerry'],
#   ['wild world'],
#   ['seemed idea'],
#   ['degree tension'],
#   ['main draw'],
#   ['many folk'],
#   ['able forget'],
#   ['unintentional surrealism'],
#   ['due sheer'],
#   ['upward sexless'],
#   ['teen implausibility'],
#   ['standard explanation'],
#   ['russian spy'],
#   ['severe fever'],
#   ['supernatural element']],
#  [['quite accident'],
#   ['give minute'],
#   ['entire film'],
#   ['old danger'],
#   ['fresh character'],
#   ['little cheesy'],
#   ['know fate'],
#   ['educational banana']],
#  [['terrible film'],
#   ['retarded comparison'],
#   ['uglier style'],
#   ['cute storyline'],
#   ['awful twin'],
#   ['good make'],
#   ['poor movie'],
#   ['unfunny comedy'],
#   ['strange character'],
#   ['serious fact'],
#   ['start cast'],
#   ['sure watch']],
#  [['wish maker'],
#   ['different pokemon'],
#   ['outer space'],
#   ['interesting brings'],
#   ['new world'],
#   ['snorlax lot'],
#   ['faulty thing'],
#   ['popular music'],
#   ['true title']],
#  [['vhs tape'], ['new stuff'], ['great family']],
#  [['spoiler opinion'],
#   ['dramatic judge'],
#   ['burlesque dancer'],
#   ['brandy rude'],
#   ['mad music'],
#   ['sexual ha'],
#   ['sexy stage'],
#   ['give break'],
#   ['worse game'],
#   ['talent age'],
#   ['grand finale']],
#  [['special tuesday'],
#   ['social type'],
#   ['bored audience'],
#   ['smart day'],
#   ['l kind'],
#   ['available nothing'],
#   ['general store'],
#   ['dry county'],
#   ['verbal masturbation'],
#   ['secret population']],
#  [['quicky studio'],
#   ['bad effort'],
#   ['big shakedown'],
#   ['douglas fairbanks'],
#   ['attractive couple'],
#   ['usual doe'],
#   ['southern accent'],
#   ['mchugh go'],
#   ['carillo day'],
#   ['sidekick cisco'],
#   ['running drug'],
#   ['modern living'],
#   ['main character'],
#   ['double bill'],
#   ['local bijou'],
#   ['early honest']],
#  [['deep movie'],
#   ['kevin walker'],
#   ['original spec'],
#   ['creative team'],
#   ['uncompromising way'],
#   ['freeman sense'],
#   ['ultimate cliché'],
#   ['old veteran'],
#   ['brash rookie'],
#   ['unnamed city'],
#   ['cheap drama'],
#   ['moral question'],
#   ['cynical older'],
#   ['much side'],
#   ['intelligent kudos'],
#   ['willing play'],
#   ['simplistic belief'],
#   ['struggle conflict'],
#   ['simple value'],
#   ['fails end'],
#   ['serial killer'],
#   ['similar view'],
#   ['fellow hate'],
#   ['sin investigation'],
#   ['undertake sermon'],
#   ['least step'],
#   ['normal hollywood'],
#   ['controversial violent'],
#   ['high level'],
#   ['grapple implication'],
#   ['direct quentin'],
#   ['extreme shock'],
#   ['genuine debate'],
#   ['dull preachy'],
#   ['finish review'],
#   ['visual talent'],
#   ['top handful'],
#   ['last burst'],
#   ['whole generation'],
#   ['available filmmaker'],
#   ['uniformly superb']],
#  [['hilarious oddity'],
#   ['special effect'],
#   ['weird way'],
#   ['enjoyable film'],
#   ['nifty performance'],
#   ['meg ryan'],
#   ['short mention'],
#   ['inventiveness direction'],
#   ['animal scientist'],
#   ['lab test'],
#   ['rival company'],
#   ['hypochondriac jack'],
#   ['change life'],
#   ['conscience trail'],
#   ['chase wackiness'],
#   ['secret service'],
#   ['old b'],
#   ['fi comedy'],
#   ['fantastic voyage'],
#   ['unique idea'],
#   ['fast pace'],
#   ['happen character'],
#   ['lead script'],
#   ['genuine laugh']],
#  [['verne book'],
#   ['easy figure'],
#   ['good actor'],
#   ['special effect'],
#   ['character end'],
#   ['original story'],
#   ['michel ardan'],
#   ['replaced woman'],
#   ['utter drivel']],
#  [['hospital marseille'],
#   ['ha memory'],
#   ['young man'],
#   ['diplomatic corp'],
#   ['big appointment'],
#   ['former master'],
#   ['criminal evidence'],
#   ['scheme convince'],
#   ['sad mgm'],
#   ['write spoiler'],
#   ['nostradamus hedy'],
#   ['faithful missus'],
#   ['felix bressart'],
#   ['star thing']],
#  [['european kingdom'],
#   ['identical look'],
#   ['attend coronation'],
#   ['evil half'],
#   ['great adventure'],
#   ['lavish treatment'],
#   ['enjoyable silky'],
#   ['ronald colman'],
#   ['rare fortunate'],
#   ['douglas fairbanks'],
#   ['young villain'],
#   ['fight stand'],
#   ['full terrific'],
#   ['madeleine carroll'],
#   ['mary astor'],
#   ['old sir'],
#   ['smith model'],
#   ['elderly devotion']],
#  [['iota doubt'],
#   ['existential existentialist'],
#   ['exact science'],
#   ['skeptical existentialism'],
#   ['negative perception'],
#   ['critical opinion'],
#   ['natural realism'],
#   ['necessary trajectory'],
#   ['next millennium'],
#   ['complementary outlook'],
#   ['chronic bout'],
#   ['clinical dyslexia']],
#  [['hidden camera'],
#   ['american living'],
#   ['high life'],
#   ['white friend'],
#   ['black embrace'],
#   ['hop culture'],
#   ['unwanted rap'],
#   ['socal hood'],
#   ['hilarious character'],
#   ['adolescent hiphop'],
#   ['demographic america'],
#   ['sean julliard'],
#   ['authentic joining'],
#   ['w e'],
#   ['proper grammar'],
#   ['nice clothes'],
#   ['perfect gangsta'],
#   ['good job'],
#   ['bothered wa'],
#   ['bad romance'],
#   ['wise drama'],
#   ['first half'],
#   ['great scene'],
#   ['strong spent'],
#   ['much time'],
#   ['snoop dogg'],
#   ['worth watch'],
#   ['familiar kid']],
#  [['eric freeman'],
#   ['first film'],
#   ['santa outfit'],
#   ['shameless excuse'],
#   ['thirty minute'],
#   ['inventive kill'],
#   ['little snippet'],
#   ['numerous reason'],
#   ['possible love'],
#   ['kaitan jennifer'],
#   ['former boyfriend'],
#   ['smart aleck'],
#   ['wrong thing'],
#   ['suburban street'],
#   ['innocent gun'],
#   ['despicable wheel'],
#   ['nun ax'],
#   ['dreadful trash']],
#  [['different level'],
#   ['bad opinion'],
#   ['teen start'],
#   ['major label'],
#   ['dramatic arc'],
#   ['formula bit'],
#   ['ha ambition'],
#   ['excessive running'],
#   ['pure fascination'],
#   ['previous post'],
#   ['stuff thanks'],
#   ['connective glue'],
#   ['full circle'],
#   ['whole thing'],
#   ['psychedelic montage'],
#   ['critical flaw'],
#   ['relative sibling'],
#   ['human interest'],
#   ['emotional wrapping'],
#   ['legendary semi'],
#   ['donahue mercury'],
#   ['white beck'],
#   ['cool end']],
#  [['cary grant'],
#   ['real problem'],
#   ['irene dunne'],
#   ['awful pickle'],
#   ['professional training'],
#   ['marital consummation'],
#   ['several desert'],
#   ['scott start'],
#   ['whole mess'],
#   ['girl woman'],
#   ['first film'],
#   ['interesting footnote'],
#   ['ta marilyn'],
#   ['doris james']],
#  [['likable pair'],
#   ['real proof'],
#   ['paranormal researcher'],
#   ['weird noise'],
#   ['sorry thing'],
#   ['actual place'],
#   ['point life']],
#  [['tough guy'],
#   ['right thing'],
#   ['interesting line'],
#   ['major role'],
#   ['much fun'],
#   ['screen time'],
#   ['noir melodrama']],
#  [['critic audience'],
#   ['welcome dollhouse'],
#   ['high school'],
#   ['poignant truth'],
#   ['redundant time'],
#   ['sh mean'],
#   ['next happiness'],
#   ['different form'],
#   ['first story'],
#   ['cerebral palsy'],
#   ['straight marcus'],
#   ['whole warms'],
#   ['pet pulitzer'],
#   ['stricken get'],
#   ['poetic process'],
#   ['human experience'],
#   ['great anger'],
#   ['former victim'],
#   ['bad bent'],
#   ['exploit documentation'],
#   ['documentary teenager'],
#   ['mark webber'],
#   ['purpose request'],
#   ['deep need'],
#   ['big goal'],
#   ['plan dream'],
#   ['documentian toby'],
#   ['enthusiastic father'],
#   ['hard question'],
#   ['enough material'],
#   ['vegetarian course'],
#   ['sight college'],
#   ['scoob place'],
#   ['teen effort'],
#   ['unsettling rage'],
#   ['middle suburbia'],
#   ['new jersey'],
#   ['satirize ask']],
#  [['perfect word'], ['light touch'], ['next year'], ['funny thing']],
#  [['wonderful movie'],
#   ['ensemble cast'],
#   ['funny performer'],
#   ['wrong wa'],
#   ['dread non'],
#   ['awful role'],
#   ['good course']],
#  [['many others'],
#   ['accurate nature'],
#   ['florid speech'],
#   ['wa day'],
#   ['great grandmother'],
#   ['nebraska case'],
#   ['invective exclamation'],
#   ['invoked deity'],
#   ['classical literature'],
#   ['popular song'],
#   ['incomprehensible u'],
#   ['necessary conveyed'],
#   ['scatological sense'],
#   ['american theatre'],
#   ['contemporary predict'],
#   ['future college'],
#   ['lit drama'],
#   ['due hbo'],
#   ['milch failure'],
#   ['experiment note'],
#   ['pas world'],
#   ['worthy end'],
#   ['struck cast'],
#   ['fourth season'],
#   ['anticipated order'],
#   ['portrayal moment'],
#   ['vague prospect'],
#   ['big hour'],
#   ['uncommitted care']],
#  [['bad script'],
#   ['true minute'],
#   ['eddie murphy'],
#   ['real estate'],
#   ['naming character'],
#   ['usual coerces'],
#   ['gracey mansion'],
#   ['inane repeat'],
#   ['final resolution'],
#   ['short bother']],
#  [['blackbeard fact'],
#   ['real name'],
#   ['mean ship'],
#   ['anne revenge'],
#   ['english colony'],
#   ['north carolina'],
#   ['friendly thing'],
#   ['historical doe'],
#   ['much guideline'],
#   ['alive point'],
#   ['find matter'],
#   ['built audience'],
#   ['loose history'],
#   ['entertaining intrigue'],
#   ['caribbean look'],
#   ['hide truth'],
#   ['shanghaied crew'],
#   ['second command'],
#   ['willing team'],
#   ['fall becomes']],
#  [['great cast'],
#   ['outstanding way'],
#   ['awful work'],
#   ['noir experience'],
#   ['k lange'],
#   ['conveyed inner'],
#   ['hillary performance'],
#   ['femme fatale'],
#   ['oh rest']],
#  [['white cause'],
#   ['whole wa'],
#   ['large man'],
#   ['many time'],
#   ['yes thing'],
#   ['tongue people'],
#   ['brutal image'],
#   ['extreme grotesque'],
#   ['extra feature'],
#   ['much genre'],
#   ['shockumentary tend'],
#   ['political view']],
#  [['oh sure'],
#   ['scorsese hour'],
#   ['dark ride'],
#   ['fashionable soho'],
#   ['new york'],
#   ['eighty lead'],
#   ['average word'],
#   ['single male'],
#   ['denizen night'],
#   ['personal favourite'],
#   ['fond term'],
#   ['many people'],
#   ['critical success'],
#   ['funny wife'],
#   ['main character'],
#   ['angle sheer']],
#  [['last winter'],
#   ['arctic plain'],
#   ['coldness emptiness'],
#   ['ecological theme'],
#   ['mixed something'],
#   ['ice nature'],
#   ['beautiful picture'],
#   ['white nothingness'],
#   ['finale mix'],
#   ['thrown cgi'],
#   ['animal product'],
#   ['strange box'],
#   ['stupid shot']],
#  [['good hobbit'],
#   ['script product'],
#   ['late night'],
#   ['give brief'],
#   ['lotr apology']],
#  [['positive nature'],
#   ['good disgrace'],
#   ['old school'],
#   ['give plot'],
#   ['open interpretation'],
#   ['random point']],
#  [['unlikely premise'],
#   ['young musician'],
#   ['charisma youth'],
#   ['american public'],
#   ['little message']],
#  [['great majority'],
#   ['photograph murder'],
#   ['silent footage'],
#   ['idiotic narration'],
#   ['particular void'],
#   ['good time'],
#   ['guess way'],
#   ['second think'],
#   ['similar nothing'],
#   ['documentary feel'],
#   ['narrative fraud'],
#   ['big musician'],
#   ['high school'],
#   ['little star']],
#  [['cheap boring'],
#   ['full joke'],
#   ['funny element'],
#   ['old disney'],
#   ['bad make'],
#   ['sorry people']],
#  [['excellent crap'],
#   ['gushy script'],
#   ['shakespearian prosaic'],
#   ['pragmatic tone'],
#   ['victorian language'],
#   ['appropriate context']],
#  [['write tv'],
#   ['porn star'],
#   ['prospective audience'],
#   ['second sound'],
#   ['good masturbation'],
#   ['little screen'],
#   ['feminist explanation'],
#   ['blow chauvanism'],
#   ['great communicator'],
#   ['unhappy individual'],
#   ['much way'],
#   ['many thing'],
#   ['false economy']],
#  [['futuristic science'],
#   ['alien race'],
#   ['powerful terl'],
#   ['natural resource'],
#   ['forgotten security'],
#   ['obvious get'],
#   ['fellow manage'],
#   ['lead men'],
#   ['richard tyson'],
#   ['fox sabine'],
#   ['sean hewitt'],
#   ['preston chirk'],
#   ['special effect'],
#   ['big waste'],
#   ['awful razzies'],
#   ['christian picture'],
#   ['screen couple']],
#  [['many time'],
#   ['excellant people'],
#   ['wa cheezy'],
#   ['flexible point'],
#   ['true legend'],
#   ['arthurian text']],
#  [['turned movie'],
#   ['hot jane'],
#   ['entire plot'],
#   ['implausible plausibility'],
#   ['good ha'],
#   ['funny moment'],
#   ['french exam'],
#   ['chuckle lot'],
#   ['suppose meant'],
#   ['whole idea'],
#   ['america france'],
#   ['enough make']],
#  [['fame kinda'],
#   ['inevitable get'],
#   ['wrong love'],
#   ['stuck guess'],
#   ['high school'],
#   ['straight boy'],
#   ['fag hag'],
#   ['vlad story'],
#   ['song movie'],
#   ['original broadway'],
#   ['favorite character'],
#   ['awesome kid'],
#   ['future talent']],
#  [['agree spoken'],
#   ['long way'],
#   ['right feel'],
#   ['mean anything'],
#   ['daily work'],
#   ['good time']],
#  [['first thing'],
#   ['classified reality'],
#   ['great deal'],
#   ['hate create'],
#   ['cool paper'],
#   ['poor man'],
#   ['comedian inherits'],
#   ['financial aspect'],
#   ['skinny babe'],
#   ['guess girl'],
#   ['physical transformation'],
#   ['enough attitude'],
#   ['unfunny detail'],
#   ['early life'],
#   ['right felt'],
#   ['natural result'],
#   ['brief success'],
#   ['instinct humor'],
#   ['digress end'],
#   ['willing give'],
#   ['whiny grow'],
#   ['good try']],
#  [['good threshold'],
#   ['super dome'],
#   ['uninspired performance'],
#   ['general act'],
#   ['small town'],
#   ['low thank'],
#   ['heavy hitter'],
#   ['happy folk'],
#   ['start project']],
#  [['intended century'],
#   ['awful drive'],
#   ['insect movie'],
#   ['serious result'],
#   ['much date'],
#   ['screwy airplane'],
#   ['naked gun'],
#   ['nice photography'],
#   ['atrocious grab'],
#   ['laugh head'],
#   ['lawless scientist'],
#   ['locust cya'],
#   ['general eager'],
#   ['equal intelligence'],
#   ['stick prop'],
#   ['unintentional humour'],
#   ['estranged boyfriend'],
#   ['specialized audience'],
#   ['guffaw time'],
#   ['scientific field'],
#   ['haired caricature'],
#   ['straight job'],
#   ['underwear model'],
#   ['low moment'],
#   ['prime line'],
#   ['unstoppable viewer'],
#   ['amazing effect'],
#   ['dark dot'],
#   ['several state'],
#   ['good performance'],
#   ['farmer cuz']],
#  [['hidden midst'],
#   ['subject matter'],
#   ['unoriginal game'],
#   ['perfect woman'],
#   ['pro con'],
#   ['magnificent script'],
#   ['give theme'],
#   ['livingston work'],
#   ['witty dialog'],
#   ['unbelievable interaction'],
#   ['personal male'],
#   ['abrupt anything'],
#   ['little elaboration']],
#  [['original astro'],
#   ['generic cgi'],
#   ['moral theme'],
#   ['ha weird'],
#   ['good guy'],
#   ['bipolar disorder'],
#   ['second act'],
#   ['ham egg'],
#   ['sudden justification'],
#   ['distinct style'],
#   ['odd design'],
#   ['anime look'],
#   ['big eye']],
#  [['tear jerker'],
#   ['beautiful kate'],
#   ['strong performance'],
#   ['pulled heart'],
#   ['final scene'],
#   ['believable job'],
#   ['superlative soundtrack'],
#   ['deep story'],
#   ['canadian history']],
#  [['many comment'],
#   ['martial art'],
#   ['drunken master'],
#   ['hardison character'],
#   ['proper month'],
#   ['uk dvd'],
#   ['full neat']],
#  [['rotten movie'],
#   ['weak variation'],
#   ['whale orca'],
#   ['lackluster grizzly'],
#   ['obnoxious teenager'],
#   ['fellow filmmaker'],
#   ['permanent damage'],
#   ['signal cell'],
#   ['thoughtless plan'],
#   ['winch break'],
#   ['private property'],
#   ['deep middle'],
#   ['appropriate toxic'],
#   ['angry momma'],
#   ['suspense scene'],
#   ['second director'],
#   ['low budget'],
#   ['usual nonsense'],
#   ['scary horror'],
#   ['human stalker'],
#   ['belong man'],
#   ['common sense'],
#   ['separate wander'],
#   ['posse personality'],
#   ['minute action'],
#   ['incline manage'],
#   ['forgettable film']],
#  [['little everything']],
#  [['saw tcm'],
#   ['mgm stock'],
#   ['wonderful need'],
#   ['old day'],
#   ['donen burton'],
#   ['united state'],
#   ['full cute'],
#   ['venerable genre'],
#   ['broadway street'],
#   ['psychoanalytic dream'],
#   ['oklahoma tale'],
#   ['secret life'],
#   ['mitty career'],
#   ['red shoe']],
#  [['dull disappointment'],
#   ['many people'],
#   ['dismal scenery'],
#   ['much problem'],
#   ['ha structure'],
#   ['plausible story'],
#   ['abused redemption'],
#   ['original industry'],
#   ['romantic comedy'],
#   ['human character'],
#   ['acceptable time'],
#   ['alone nuance'],
#   ['emotional tenor'],
#   ['anguish sorrow'],
#   ['minor chord'],
#   ['spectrum hint'],
#   ['cliché thing'],
#   ['difficult man'],
#   ['survival skill'],
#   ['great deal'],
#   ['physical reaction'],
#   ['intellectual masochism'],
#   ['sympathetic trudging'],
#   ['cheated reliance'],
#   ['apocalyptic world'],
#   ['empty colourless'],
#   ['devoid relationship'],
#   ['sure father'],
#   ['unconditional child'],
#   ['cultural radar'],
#   ['new clothes']],
#  [['tremendous leap'],
#   ['wooden pun'],
#   ['wonderful co'],
#   ['international singing'],
#   ['young girl'],
#   ['mountainside home'],
#   ['mean mister'],
#   ['bad news'],
#   ['strongest role'],
#   ['strong seller'],
#   ['seasonal holiday']],
#  [['documentary sort'],
#   ['dead b'],
#   ['mockumentary awkward'],
#   ['spinal tap'],
#   ['tall order'],
#   ['disappointed world'],
#   ['screen time'],
#   ['porn star'],
#   ['potential type'],
#   ['short applaud'],
#   ['hick side'],
#   ['whole decide'],
#   ['conventional story'],
#   ['inexplicable camera'],
#   ['private reaction']],
#  [['high hope'],
#   ['madhuri dixit'],
#   ['great fan'],
#   ['repetitive speak'],
#   ['sure ha'],
#   ['give ten'],
#   ['good comment'],
#   ['ur watch']],
#  [['conceivable reason'],
#   ['airtime comparison'],
#   ['long term'],
#   ['confused krista'],
#   ['ash drug'],
#   ['short burst'],
#   ['vampiric power'],
#   ['previous backstory'],
#   ['next pa'],
#   ['tic let'],
#   ['charismatic perky'],
#   ['angel fan'],
#   ['sticky finger'],
#   ['see action'],
#   ['interesting agent'],
#   ['coming grip'],
#   ['extra producer'],
#   ['driven heart'],
#   ['blame director']],
#  [['original idea'],
#   ['much boy'],
#   ['telekinetic power'],
#   ['evil build'],
#   ['tight end'],
#   ['supernatural stuff'],
#   ['friday part'],
#   ['favourite scene'],
#   ['mere cause'],
#   ['good horror'],
#   ['critic fun'],
#   ['stupid hate'],
#   ['many film']],
#  [['stunned comment'],
#   ['bad author'],
#   ['wa masterpiece'],
#   ['rip dialogue'],
#   ['much effort'],
#   ['poor actor'],
#   ['obvious attempt'],
#   ['live past'],
#   ['give kind'],
#   ['tedious stereotype'],
#   ['end mass'],
#   ['oversimplified joke'],
#   ['omfg way'],
#   ['insulting audience'],
#   ['open fact']],
#  [['good moment'],
#   ['wonderful direction'],
#   ['minute movie'],
#   ['small town'],
#   ['old everybody'],
#   ['sixteen year'],
#   ['grey wig'],
#   ['gorgeous enjoyed']],
#  [['laughable garbage'],
#   ['worth time'],
#   ['negative opinion'],
#   ['artful expression'],
#   ['avoid cost'],
#   ['severe gay'],
#   ['undertone diamond'],
#   ['decent talan'],
#   ['awful guy']],
#  [['controversial figure'],
#   ['unable part'],
#   ['irrespective belief'],
#   ['historical character'],
#   ['last movie'],
#   ['cinematic aspect'],
#   ['end second'],
#   ['many form'],
#   ['revolutionary ideal'],
#   ['long absent'],
#   ['ultimate stand'],
#   ['collective thinking'],
#   ['bad feel'],
#   ['smoother transition'],
#   ['linear sort'],
#   ['avoid running'],
#   ['bolivian diary'],
#   ['cuban revolution'],
#   ['attempt think'],
#   ['stylistic approach'],
#   ['symphony bit'],
#   ['underrated america'],
#   ['cold war']],
#  [['lame pilot'],
#   ['crappy v'],
#   ['stranded space'],
#   ['ground imagine'],
#   ['give credit'],
#   ['yellowish mess'],
#   ['tab hunter'],
#   ['long time'],
#   ['first scene'],
#   ['entire plane'],
#   ['lesson congressman'],
#   ['box wife'],
#   ['weenie kid'],
#   ['pete macgyver'],
#   ['fist fight'],
#   ['much sense'],
#   ['bad irritating'],
#   ['yellow look'],
#   ['pic coffee'],
#   ['whole thing'],
#   ['sleep inducer'],
#   ['total waste']],
#  [['old men'],
#   ['overwrought misanthropic'],
#   ['violent account'],
#   ['indestructible hit'],
#   ['customary luminosity'],
#   ['fourteenth movie'],
#   ['struggle side'],
#   ['big lebowski'],
#   ['forgettable farce'],
#   ['previous misfire'],
#   ['intolerable cruelty'],
#   ['tom clancy'],
#   ['spy satellite'],
#   ['bay area'],
#   ['c headquarters'],
#   ['ozzie cox'],
#   ['innocent relief'],
#   ['volatile spews'],
#   ['inferior job'],
#   ['reassigned storm'],
#   ['fist scene'],
#   ['personal trainer'],
#   ['cosmetic procedure'],
#   ['flabby physique'],
#   ['whine plastic'],
#   ['elective operation'],
#   ['ted richard'],
#   ['chad feldheimer'],
#   ['ocean twelve'],
#   ['ipod jewelry'],
#   ['anonymous computer'],
#   ['lady locker'],
#   ['wish blackmail'],
#   ['meanwhile ice'],
#   ['tilda swinton'],
#   ['u marshal'],
#   ['mechanical sex'],
#   ['successful child'],
#   ['dime approach'],
#   ['russian embassy'],
#   ['ensemble piece'],
#   ['erratic script'],
#   ['farcical yarn'],
#   ['unsavory dimwit'],
#   ['moronic fool'],
#   ['comic sens'],
#   ['sophisticated humor'],
#   ['flat face'],
#   ['pediatrician bedside'],
#   ['delusional cretin'],
#   ['thought thing'],
#   ['eclectic gallery'],
#   ['prompt anything'],
#   ['infidelity espionage'],
#   ['hyperactive le'],
#   ['hokum failure'],
#   ['multiple level'],
#   ['poor plotting'],
#   ['sudden lapse']],
#  [['british comedy'],
#   ['slightest titter'],
#   ['considerable talent'],
#   ['dire entertainment'],
#   ['weekly repertory'],
#   ['gold producer'],
#   ['first rehearsal'],
#   ['squabble cast'],
#   ['fleeting appearance'],
#   ['finale ambulance'],
#   ['funny moment'],
#   ['facial expression'],
#   ['sit foot']],
#  [['sure everyone'],
#   ['first time'],
#   ['major disappointment'],
#   ['enjoyed animation'],
#   ['notice difference'],
#   ['fit character'],
#   ['new chapter'],
#   ['become prince'],
#   ['favorite friend'],
#   ['hard father'],
#   ['fear enemy'],
#   ['learn grieve'],
#   ['total pleasure'],
#   ['good movie']],
#  [['original movie'],
#   ['psychopathic ticket'],
#   ['short segment'],
#   ['musical indifferencies'],
#   ['indian immigrant'],
#   ['sexual orientation'],
#   ['pretentious manages'],
#   ['funny time'],
#   ['bad taste'],
#   ['pretty experience']],
#  [['mary cherry'],
#   ['true homage'],
#   ['teen life'],
#   ['late ninety'],
#   ['thereof alcoholism'],
#   ['comedy heart']],
#  [['topical story'],
#   ['due work'],
#   ['able watch'],
#   ['early watching'],
#   ['many version'],
#   ['real feel'],
#   ['next hold'],
#   ['obsessed gibbs']],
#  [['great movie'],
#   ['big budget'],
#   ['photographic technique'],
#   ['worth lionel']],
#  [['tonga movie'],
#   ['important detail'],
#   ['good cast'],
#   ['outstanding scenery'],
#   ['faithful knock'],
#   ['worldly way'],
#   ['latter day'],
#   ['sceptical ability'],
#   ['missionary heal'],
#   ['true story'],
#   ['worked miracle'],
#   ['young mormon'],
#   ['different opinion'],
#   ['notable exception'],
#   ['nice see'],
#   ['whole family']],
#  [['terrible mistake'], ['admirable cast'], ['good time'], ['alan parker']],
#  [['taylor part'], ['fish water'], ['superior garbage'], ['bright moment']],
#  [['first look'],
#   ['serious hangover'],
#   ['satya company'],
#   ['new offer'],
#   ['senior crime'],
#   ['negative manner'],
#   ['realistic transition'],
#   ['individual turning'],
#   ['randeep hooda'],
#   ['chakraverthy time'],
#   ['shade speak'],
#   ['min pace'],
#   ['inspired grittiness'],
#   ['local scenery'],
#   ['gang rivalry'],
#   ['different angle'],
#   ['sudden death'],
#   ['relative becomes'],
#   ['side law'],
#   ['join popularity'],
#   ['attempt hinder'],
#   ['designated area'],
#   ['bitter end'],
#   ['good camera'],
#   ['wide howver'],
#   ['sound pleasure'],
#   ['acceptable performance'],
#   ['second half'],
#   ['future hope'],
#   ['indian release'],
#   ['sure check']],
#  [['distant past'],
#   ['great samurai'],
#   ['izo wa'],
#   ['heinous manner'],
#   ['many fan'],
#   ['japanese cinema'],
#   ['takeshi kitano'],
#   ['easier comment'],
#   ['much flawless'],
#   ['good see'],
#   ['le horror'],
#   ['get share'],
#   ['questionable perversity'],
#   ['old voice'],
#   ['spray swordplay'],
#   ['enjoyable variety'],
#   ['countless stabbings'],
#   ['hooked philosophy'],
#   ['grasp mythology'],
#   ['abstract term'],
#   ['alive stay'],
#   ['appreciate fairness'],
#   ['animalistic form']],
#  [['last night'],
#   ['german city'],
#   ['fantastic soundtrack'],
#   ['electronic music'],
#   ['great cast'],
#   ['girl course'],
#   ['right see'],
#   ['big world'],
#   ['loneliness accompanies'],
#   ['know belongs']],
#  [['secret rival'],
#   ['storyline actor'],
#   ['fu movie'],
#   ['good deal'],
#   ['excellent practice'],
#   ['poor picture'],
#   ['visible course'],
#   ['available dvd'],
#   ['clear crisp'],
#   ['classic rating']],
#  [['imdb matter'],
#   ['awful film'],
#   ['ten star'],
#   ['listed doe'],
#   ['hard promise'],
#   ['real moment'],
#   ['young daughter'],
#   ['emotional parent'],
#   ['terrible ha'],
#   ['little research'],
#   ['actual movie'],
#   ['good yes']],
#  [['loved picture'],
#   ['beautiful cinematography'],
#   ['uma thurman'],
#   ['ward charm'],
#   ['tricky anais'],
#   ['american writer'],
#   ['new york'],
#   ['accent beauty'],
#   ['astonish epic'],
#   ['video store']],
#  [['past regain'],
#   ['upbeat comedy'],
#   ['important forward'],
#   ['usual self'],
#   ['low budget']],
#  [['middle child'],
#   ['tab hunter'],
#   ['particular delight'],
#   ['dangerous mountain'],
#   ['valley begin'],
#   ['outdoor adventure'],
#   ['frontier drama'],
#   ['unsympathetic character'],
#   ['good performance'],
#   ['female cast'],
#   ['else offer'],
#   ['escapist entertainment'],
#   ['low budget'],
#   ['big cat'],
#   ['phil karlson']],
#  [['local video'],
#   ['rental store'],
#   ['right minute'],
#   ['shiny knife'],
#   ['want people'],
#   ['comical hour']],
#  [['valiant collector'],
#   ['american epic'],
#   ['many page'],
#   ['great villain'],
#   ['middle rest'],
#   ['enjoyable rick']],
#  [['first time'],
#   ['low budget'],
#   ['good story'],
#   ['favorite part'],
#   ['saturday morning'],
#   ['basic design'],
#   ['fine consider'],
#   ['cool thing'],
#   ['awesome sci']],
#  [['east side'],
#   ['early mid'],
#   ['walk street'],
#   ['f ck'],
#   ['highlight jerry'],
#   ['reminiscent jackal'],
#   ['classic revenge'],
#   ['pinched tart'],
#   ['st yes'],
#   ['disneyfied shrager'],
#   ['beg token'],
#   ['outpost wallet'],
#   ['lifted balcony'],
#   ['triple feature'],
#   ['lisa deleeuw'],
#   ['great performance'],
#   ['porn director'],
#   ['young hunk'],
#   ['dumb hung'],
#   ['assertive protege'],
#   ['next door'],
#   ['enjoy slice']],
#  [['wonderful film'],
#   ['interesting intelligent'],
#   ['education buddhism'],
#   ['real appreciation'],
#   ['independent feeling'],
#   ['comic team'],
#   ['whole self'],
#   ['alternative theater'],
#   ['certain level'],
#   ['many joke'],
#   ['middle half'],
#   ['german speaker'],
#   ['buddhist practice'],
#   ['major source']],
#  [['political taboo'],
#   ['terrible foul'],
#   ['politician espouses'],
#   ['liberal platitude'],
#   ['real arena'],
#   ['wrong trot'],
#   ['laughable movie']],
#  [['conceptual level'],
#   ['saw poster'],
#   ['wa disappointment'],
#   ['good thing'],
#   ['intriguing twist'],
#   ['n turn'],
#   ['mental battle'],
#   ['last day'],
#   ['legendary try'],
#   ['virus mixture'],
#   ['ecological footprint'],
#   ['new energy'],
#   ['efficient technology'],
#   ['green crusader'],
#   ['small math'],
#   ['old charm'],
#   ['average viewer'],
#   ['enough stretch'],
#   ['secret service'],
#   ['lil kid'],
#   ['disabled end']],
#  [['blemish status'],
#   ['akira kurosawa'],
#   ['japanese filmmaker'],
#   ['last night'],
#   ['classic noir'],
#   ['regular toshirô'],
#   ['firearm pick'],
#   ['bus becomes'],
#   ['desperate murdering'],
#   ['criminal det'],
#   ['guilt shame'],
#   ['overcome insecurity'],
#   ['third wealth'],
#   ['illustrious career'],
#   ['many regard'],
#   ['neorealist bicycle'],
#   ['futile search'],
#   ['essential stolen'],
#   ['individual aftermath'],
#   ['economic difficulty'],
#   ['gun wonderful'],
#   ['stricken street'],
#   ['darkened path'],
#   ['important theme'],
#   ['parallel yusa'],
#   ['crucial step'],
#   ['climactic chase'],
#   ['undergrowth face'],
#   ['layer mud'],
#   ['decisive moment'],
#   ['extreme heatwave'],
#   ['skin actor'],
#   ['climax arrival'],
#   ['routine procedure'],
#   ['grapple vegetation'],
#   ['massive undertaking']],
#  [['serial killer'],
#   ['several sub'],
#   ['exotic piercing'],
#   ['primal fear'],
#   ['whole dennis'],
#   ['noteworthy performance'],
#   ['savior struggle'],
#   ['reminiscent al'],
#   ['dramatic subterfuge'],
#   ['single dad'],
#   ['thick sloshes'],
#   ['standard shake'],
#   ['playful v'],
#   ['easy please'],
#   ['doe hold']],
#  [['awful struggle'],
#   ['nazi regime'],
#   ['interested topic'],
#   ['small kid'],
#   ['necessary sell']],
#  [['historical note'],
#   ['ton picture'],
#   ['traditional view'],
#   ['wagnerian people'],
#   ['wonderful movie'],
#   ['false read'],
#   ['much wa'],
#   ['sorry spoil'],
#   ['daddy donald'],
#   ['crisp court'],
#   ['knight friend'],
#   ['hair victor'],
#   ['mclaglen way'],
#   ['ha kingdom'],
#   ['send son'],
#   ['uk serve'],
#   ['scandinavia kind'],
#   ['dirty deal'],
#   ['midst traitor'],
#   ['wish bash'],
#   ['new career'],
#   ['advancement knighthood'],
#   ['noble dude'],
#   ['peasant lord'],
#   ['various war'],
#   ['chivalrous group'],
#   ['nice touch'],
#   ['twentieth century'],
#   ['great music'],
#   ['costume location'],
#   ['late time'],
#   ['anachronistic dull'],
#   ['dumb janet'],
#   ['leigh confronts'],
#   ['minute mark'],
#   ['flat actor'],
#   ['hayden place'],
#   ['plum role'],
#   ['fit play'],
#   ['macho cattle'],
#   ['disrespect action'],
#   ['young studio'],
#   ['right accent'],
#   ['borgnine mature'],
#   ['good siege'],
#   ['attempted murder'],
#   ['enough actiony'],
#   ['inaccurate lot'],
#   ['first class'],
#   ['terrible heck'],
#   ['holy grail']],
#  [['original latch'],
#   ['old channel'],
#   ['late afternoon'],
#   ['untouchable highway'],
#   ['big valley']],
#  [['user review'],
#   ['j c'],
#   ['invented time'],
#   ['pyun direction'],
#   ['ha year'],
#   ['whhaaa azzzzzuuuupppppp'],
#   ['atlanta fight'],
#   ['wwf pay']],
#  [['insist comedy'],
#   ['bad sidekick'],
#   ['great skip'],
#   ['american pie'],
#   ['nay buy'],
#   ['spinal tap'],
#   ['guffman comparison'],
#   ['tired run']],
#  [['total disaster'],
#   ['turkey make'],
#   ['star war'],
#   ['second comedy'],
#   ['important world'],
#   ['american people'],
#   ['turkish population'],
#   ['different opinion'],
#   ['much please']],
#  [['hr start'],
#   ['vicious killer'],
#   ['san francisco'],
#   ['reggie hammond'],
#   ['detective jack'],
#   ['nick nolte'],
#   ['powerful drug'],
#   ['iceman shoot'],
#   ['jeb stuart'],
#   ['internal affair'],
#   ['mysterious fact'],
#   ['free man'],
#   ['side nothing'],
#   ['complete rehash'],
#   ['similar time'],
#   ['buddy cop'],
#   ['bad language'],
#   ['fight bit'],
#   ['hard director'],
#   ['alright look'],
#   ['ridden brion'],
#   ['huge chunk'],
#   ['third opening'],
#   ['strong gory'],
#   ['solid r'],
#   ['near weekend'],
#   ['big budget'],
#   ['shot los'],
#   ['good lead'],
#   ['full seem'],
#   ['slight improvement'],
#   ['worth watch']],
#  [['documentary book'],
#   ['die heard'],
#   ['good music'],
#   ['extra footage'],
#   ['new york'],
#   ['side stage'],
#   ['live aid'],
#   ['beat history'],
#   ['big festival'],
#   ['fish crosby'],
#   ['ten year'],
#   ['sound number']],
#  [['distinguishing feature'],
#   ['private school'],
#   ['mean penis'],
#   ['make allusion'],
#   ['violent man'],
#   ['change thing'],
#   ['popular osbournes'],
#   ['single track'],
#   ['pas art']],
#  [['big brother'],
#   ['sect difference'],
#   ['live dark'],
#   ['prisoner fact'],
#   ['actual filming'],
#   ['nude toilet'],
#   ['thought whole']],
#  [['memorable moment'],
#   ['commercial porpoise'],
#   ['manliness morality'],
#   ['friendship story'],
#   ['amazing battle'],
#   ['aggrieved week'],
#   ['main character'],
#   ['follow reason']],
#  [['single actor'],
#   ['attractive bore'],
#   ['second day'],
#   ['romantic comedy'],
#   ['ease simplicity'],
#   ['nostalgic tone'],
#   ['rare occasion'],
#   ['special effect'],
#   ['beautiful mood']],
#  [['quiet laughter'],
#   ['laugh movie'],
#   ['cary grant'],
#   ['comedic flair'],
#   ['bad character'],
#   ['lousy screenplay'],
#   ['cool intelligence'],
#   ['cynical remark'],
#   ['need story'],
#   ['usual irene'],
#   ['close ups'],
#   ['visible tongue'],
#   ['open mouth'],
#   ['attempt lack']],
#  [['triple thing'],
#   ['raw sewage'],
#   ['low rent'],
#   ['teen rocker'],
#   ['boyfriend figure'],
#   ['dead drivel'],
#   ['english casket']],
#  [['main virtue'],
#   ['unbeatable whodunit'],
#   ['great filmmaker'],
#   ['fine star'],
#   ['ustinov bette'],
#   ['angela lansbury'],
#   ['warden stand'],
#   ['eccentric albert'],
#   ['nice costume'],
#   ['natural location'],
#   ['strong director'],
#   ['repetitive show'],
#   ['possible version'],
#   ['first half'],
#   ['handle action'],
#   ['belgian detective'],
#   ['second compensates']],
#  [['main kid'],
#   ['softest voice'],
#   ['imagine threat'],
#   ['accent mention'],
#   ['good thing'],
#   ['useful head'],
#   ['full blonde'],
#   ['british nuff']],
#  [['german movie'],
#   ['good forget'],
#   ['loveparade berlin'],
#   ['wild beat'],
#   ['modern camera'],
#   ['full drug'],
#   ['chaos boyfriend'],
#   ['terrible film'],
#   ['conscious guilt'],
#   ['guy punishment']],
#  [['original visuals'],
#   ['much recreate'],
#   ['screen way'],
#   ['faithful fan'],
#   ['real surefire'],
#   ['first entry'],
#   ['great wa'],
#   ['enjoyable action'],
#   ['overall design'],
#   ['fun death'],
#   ['direct continuation'],
#   ['devastated raccoon'],
#   ['deep watch'],
#   ['evil visual']],
#  [['good concept'], ['horrible performance'], ['individual world']],
#  [['excellent surprise'],
#   ['normal shoot'],
#   ['em drama'],
#   ['thirty minute'],
#   ['good guy'],
#   ['awesome role'],
#   ['overall tense'],
#   ['suspense humor'],
#   ['great deal'],
#   ['unexpected turn']],
#  [['documentary film'],
#   ['darwinian evolution'],
#   ['kansa school'],
#   ['good movie'],
#   ['know side'],
#   ['expect randy'],
#   ['witty remark'],
#   ['right consist'],
#   ['next room'],
#   ['follow presentation'],
#   ['evolutionary biologist'],
#   ['coral community'],
#   ['sharp guy'],
#   ['negative something'],
#   ['ironic nature'],
#   ['antagonistic group'],
#   ['existential proposition'],
#   ['hortative mean'],
#   ['different order'],
#   ['evolutionist zealot'],
#   ['present case'],
#   ['common people'],
#   ['sense term'],
#   ['public relation'],
#   ['republican democrat'],
#   ['senior seminar'],
#   ['scientific copernicus'],
#   ['equal weight'],
#   ['wa time'],
#   ['irritating okay'],
#   ['insert work'],
#   ['numerous others'],
#   ['u tv'],
#   ['congratulatory wince'],
#   ['general george'],
#   ['subtle elitism'],
#   ['introduced doctor'],
#   ['virtue exploration'],
#   ['theological interpretation'],
#   ['disappear figure'],
#   ['afraid challenge'],
#   ['american believe'],
#   ['presidential candidate']],
#  [['offbeat version'],
#   ['new york'],
#   ['contemporary reference'],
#   ['funny time'],
#   ['fresh cool'],
#   ['lame suspicion'],
#   ['famous death'],
#   ['tony randall'],
#   ['successful tv'],
#   ['groucho marx'],
#   ['cameo end'],
#   ['good comedy']],
#  [['new tv'],
#   ['title character'],
#   ['former police'],
#   ['detective suffers'],
#   ['compulsive disorder'],
#   ['much humor'],
#   ['middle path'],
#   ['human dignity'],
#   ['humorous situation'],
#   ['weekly villain'],
#   ['dimensional dunce'],
#   ['regular role'],
#   ['doo end'],
#   ['bad guy'],
#   ['sexy nurse'],
#   ['procedural yes'],
#   ['main goal'],
#   ['accept combination'],
#   ['encyclopedic knowledge'],
#   ['swallow addition'],
#   ['preternatural genius'],
#   ['legwork research'],
#   ['average network'],
#   ['several episode'],
#   ['right borderline']],
#  [['second tom'],
#   ['much merit'],
#   ['passable watching'],
#   ['ward female'],
#   ['former fiancé'],
#   ['thompson end'],
#   ['multiple part'],
#   ['good job'],
#   ['wealthy industrialist'],
#   ['entry policeman'],
#   ['important character'],
#   ['fair viewer'],
#   ['unexplained event'],
#   ['modern audience'],
#   ['hear word'],
#   ['understand significance'],
#   ['critical clue'],
#   ['true culprit'],
#   ['pretty woman']],
#  [['ol snagglepuss'],
#   ['dee place'],
#   ['paragraph end'],
#   ['super chunk'],
#   ['quick draw'],
#   ['graduate school']],
#  [['total waste'],
#   ['soft porn'],
#   ['sister try'],
#   ['naive police'],
#   ['resist siren'],
#   ['apart couple'],
#   ['nightmarish sequence'],
#   ['cannibalistic trademark'],
#   ['late example'],
#   ['italian giallo']],
#  [['classic scene'],
#   ['tv aquarium'],
#   ['censored word'],
#   ['entire meaningless'],
#   ['first time'],
#   ['major film'],
#   ['great comedy'],
#   ['funny way']],
#  [['give movie'], ['special effect'], ['interested story']],
#  [['terrible flick'],
#   ['bad plot'],
#   ['special effect'],
#   ['suspense thrill'],
#   ['miserable movie'],
#   ['campy way'],
#   ['ridiculous mess']],
#  [['captured attention'],
#   ['several week'],
#   ['dvd luck'],
#   ['future release'],
#   ['historical love'],
#   ['give performance'],
#   ['someday company']],
#  [['nasty pimp'],
#   ['future step'],
#   ['portrayed tv'],
#   ['pas school'],
#   ['former client'],
#   ['hidden car'],
#   ['bos pressure']],
#  [['great performance'],
#   ['detective tail'],
#   ['fun movie'],
#   ['beautiful daphne'],
#   ['american dream'],
#   ['police officer'],
#   ['body criminal'],
#   ['vet amanda'],
#   ['ward dorien'],
#   ['pete antico']],
#  [['small kid'],
#   ['outside wood'],
#   ['key scene'],
#   ['dead hotel'],
#   ['ebay ride'],
#   ['full adventure'],
#   ['random town'],
#   ['nostalgia movie']],
#  [['feature family'],
#   ['safe pg'],
#   ['drunkard rock'],
#   ['girl outfit'],
#   ['dual role'],
#   ['pitiful rocker'],
#   ['destructive part'],
#   ['painful watch'],
#   ['enough text'],
#   ['u rent'],
#   ['fair lady']],
#  [['beautiful scenery'],
#   ['finish film'],
#   ['bambi look'],
#   ['dirty dozen'],
#   ['accurate deer'],
#   ['nasa solve'],
#   ['high example'],
#   ['bad guy'],
#   ['white yes'],
#   ['coalface end'],
#   ['sorry disillusion'],
#   ['african city'],
#   ['middle fact'],
#   ['mexican game'],
#   ['plausible facility'],
#   ['abercrombe kent'],
#   ['forced work'],
#   ['many school'],
#   ['modern day'],
#   ['type figure'],
#   ['spent time']],
#  [['wonderful scenery'], ['whole lot'], ['comical film']],
#  [['historical movie'],
#   ['disregard history'],
#   ['elizabeth figure'],
#   ['actual fact'],
#   ['lady jane'],
#   ['old girl'],
#   ['butchered life'],
#   ['good plenty'],
#   ['stick topic']],
#  [['overall mediocrity'],
#   ['many joke'],
#   ['bad question'],
#   ['insignificant twist'],
#   ['happens end']],
#  [['easy girl'],
#   ['funny movie'],
#   ['bad humor'],
#   ['american pie'],
#   ['oh actor'],
#   ['many reviewer'],
#   ['boring honest'],
#   ['teen comedy']],
#  [['dreadful sci'],
#   ['fi entry'],
#   ['onslaught place'],
#   ['dead woman'],
#   ['high school'],
#   ['clever lady'],
#   ['pull wool'],
#   ['stupid parent'],
#   ['human path'],
#   ['live chicken'],
#   ['rid outer'],
#   ['much gripping'],
#   ['special effect']],
#  [['great film'],
#   ['different opinion'],
#   ['know guess'],
#   ['happy see'],
#   ['decent trust'],
#   ['british comedy'],
#   ['glue submarine'],
#   ['notice buy']],
#  [['low budget'],
#   ['last day'],
#   ['local inn'],
#   ['unsociable man'],
#   ['hanson christopher'],
#   ['hot mainland'],
#   ['novel woman'],
# ...
#   ['attractive get'],
#   ['artificial insemination'],
#   ['plead subtlety'],
#   ['subtle sledgehammer'],
#   ['mean river'],
#   ['lame dialogue'],
#   ['co writer'],
#   ['brian dennehy'],
#   ['corrupt business'],
#   ['tie administration'],
#   ['collar crook'],
#   ['easy wind'],
#   ['successful life'],
#   ['satirical society'],
#   ['funny provocative']],
#  [['good genius'],
#   ['bad loss'],
#   ['dvd bed'],
#   ['open mouth'],
#   ['puppy try'],
#   ['screenplay justification'],
#   ['poor wont'],
#   ['typicall thriller'],
#   ['potential killer'],
#   ['rubbish please']],
#  [['unfaithful pair'],
#   ['serial adulterer'],
#   ['many lady'],
#   ['neurotic spouse'],
#   ['build friendship'],
#   ['sleep sympathy'],
#   ['positive lasting']],
#  [['documentary living'],
#   ['ocean wa'],
#   ['good footage'],
#   ['ok narrator'],
#   ['pun movie'],
#   ['short minute'],
#   ['lackadaisical effort'],
#   ['new age'],
#   ['natural sound'],
#   ['strive fact']],
#  [['popular movie'],
#   ['ocean liner'],
#   ['moira shearer'],
#   ['bad ticker'],
#   ['ungrateful brat'],
#   ['ricky nelson'],
#   ['touched power'],
#   ['former star'],
#   ['suicidal pier'],
#   ['new partner'],
#   ['big top'],
#   ['narrative protagonist'],
#   ['recall information'],
#   ['last chapter'],
#   ['gymnastic move'],
#   ['g production'],
#   ['form picture'],
#   ['lengthy credit'],
#   ['tree branch'],
#   ['hypnotic dialogue'],
#   ['flourish agnes'],
#   ['mercurial angst'],
#   ['sumptuous bag'],
#   ['overall result']],
#  [['installment paul'],
#   ['hogan franchise'],
#   ['mick family'],
#   ['gal sue'],
#   ['strangest culture'],
#   ['outback skill'],
#   ['enjoyable spoof'],
#   ['love adventure']],
#  [['good emotion'],
#   ['green fertile'],
#   ['granite pumice'],
#   ['impressive sight'],
#   ['first time'],
#   ['commercial minute'],
#   ['real character'],
#   ['truman carney'],
#   ['old soldier'],
#   ['die land'],
#   ['late johnston'],
#   ['local businessmen'],
#   ['official hit'],
#   ['common ground'],
#   ['tim thomerson'],
#   ['usual stand'],
#   ['routine guy'],
#   ['untrue opinion'],
#   ['unnecessary country'],
#   ['western yokel'],
#   ['come thing'],
#   ['young geologist'],
#   ['fast work'],
#   ['lyric sound'],
#   ['huge disaster'],
#   ['surprised roadside'],
#   ['quake power'],
#   ['lava chunk']],
#  [['several anachronism'],
#   ['epoch woman'],
#   ['impossible leader'],
#   ['spy way'],
#   ['fandorin act'],
#   ['possible day'],
#   ['russian army'],
#   ['hard man'],
#   ['stupid movie'],
#   ['non stop'],
#   ['bulgarian playing'],
#   ['good idea']],
#  [['impressive production'],
#   ['true story'],
#   ['russian émigré'],
#   ['french wife'],
#   ['boy heyday'],
#   ['coldwar stalin'],
#   ['civil war'],
#   ['heaven promote'],
#   ['torn economy'],
#   ['surprising view'],
#   ['soviet russia'],
#   ['human material'],
#   ['euphoric returnees'],
#   ['economic fabric'],
#   ['excitement fear'],
#   ['hundred tragedy'],
#   ['notorious reputation'],
#   ['historical truth'],
#   ['eastern europe'],
#   ['dance scene'],
#   ['bulgarian boundary'],
#   ['snow balkan'],
#   ['denmark germany'],
#   ['online credit'],
#   ['mega store'],
#   ['possible purchasing'],
#   ['great contribution'],
#   ['u feel']],
#  [['x men'],
#   ['rare treat'],
#   ['comic book'],
#   ['tim burton'],
#   ['cartoonish crap'],
#   ['awaited exception'],
#   ['stylish cool'],
#   ['fi fantasy'],
#   ['last decade'],
#   ['good source'],
#   ['american way'],
#   ['prevail series'],
#   ['parable individuality'],
#   ['find place'],
#   ['primary villain'],
#   ['lunatic sympathetic'],
#   ['revolutionary playing'],
#   ['iconic wolverine'],
#   ['ideal fight'],
#   ['flashy explosion'],
#   ['special effect'],
#   ['big budget'],
#   ['whole hugh'],
#   ['fantastic bona'],
#   ['cheesy hand'],
#   ['ian mckellan'],
#   ['patrick stewart'],
#   ['hard core'],
#   ['paquin rogue'],
#   ['touch human'],
#   ['tremendous job'],
#   ['fear isolation'],
#   ['young woman'],
#   ['grow part'],
#   ['future end'],
#   ['babble revolves'],
#   ['straight face'],
#   ['citizen kane'],
#   ['intelligent people']],
#  [['undercooked look'],
#   ['uk plenty'],
#   ['good person'],
#   ['nifty sense'],
#   ['gratuitous murder'],
#   ['young buddhist'],
#   ['nice han'],
#   ['used car'],
#   ['next thing'],
#   ['prostitute need'],
#   ['marvelous charlotte'],
#   ['british petty'],
#   ['occasional laugh'],
#   ['strong charming'],
#   ['beautiful character'],
#   ['stunning actress'],
#   ['true murderer']],
#  [['rodney dangerfield'],
#   ['top billing'],
#   ['percent film'],
#   ['funny line'],
#   ['told wife'],
#   ['ok sex'],
#   ['real star'],
#   ['annoying time'],
#   ['dart thought'],
#   ['comic opportunity'],
#   ['gag example'],
#   ['famous goodfellas'],
#   ['give think'],
#   ['hot compensation'],
#   ['devoid laugh'],
#   ['tedious mind'],
#   ['exist choice']],
#  [['first thing'],
#   ['open mind'],
#   ['work time'],
#   ['uk tv'],
#   ['secret phantom'],
#   ['stuck year'],
#   ['vid cover'],
#   ['find dvd'],
#   ['u title'],
#   ['happy man'],
#   ['great fun'],
#   ['british actor'],
#   ['doe lift'],
#   ['recognisable voice'],
#   ['good use'],
#   ['atmospheric monologue'],
#   ['stalagmite goliath'],
#   ['meet face'],
#   ['flesh eater'],
#   ['lisa blount'],
#   ['timothy bottom'],
#   ['general motto'],
#   ['cheap think'],
#   ['feature version'],
#   ['real mishap'],
#   ['context matter'],
#   ['long bit'],
#   ['hope inspire'],
#   ['big pinch'],
#   ['ready enjoy']],
#  [['fritz cat'],
#   ['anthropomorphic view'],
#   ['animal use'],
#   ['stir reaction'],
#   ['different production'],
#   ['essential feeling'],
#   ['open mind'],
#   ['stuff wa'],
#   ['true life'],
#   ['whole thing'],
#   ['bad schoolboy'],
#   ['smutty bit'],
#   ['nazi germany'],
#   ['worth trouble'],
#   ['fanatical completest']],
#  [['blockbuster year'],
#   ['bad construction'],
#   ['info others'],
#   ['median tom'],
#   ['good cause'],
#   ['like change'],
#   ['end sake'],
#   ['louvre piramid'],
#   ['wath director']],
#  [['sendup flick'],
#   ['teen movie'],
#   ['single laugh'],
#   ['high school'],
#   ['nebbish campbell'],
#   ['young gal'],
#   ['former girlfriend'],
#   ['spoil marriage'],
#   ['familiar face'],
#   ['various parent'],
#   ['unfunny somehow'],
#   ['first meet'],
#   ['tiny bikini'],
#   ['slow mo'],
#   ['hanigan comment'],
#   ['sultry scene'],
#   ['next whip'],
#   ['sequence end']],
#  [['type myst'], ['unique way']],
#  [['first time'],
#   ['whole wonderful'],
#   ['smile face'],
#   ['favorite actor'],
#   ['last part'],
#   ['uplifting experience'],
#   ['compatible family'],
#   ['academy needle'],
#   ['guy thing'],
#   ['sheik spoke'],
#   ['tho crane'],
#   ['spanish horsey'],
#   ['good prince']],
#  [['snotty bitch'],
#   ['special effect'],
#   ['bad fake'],
#   ['ant farm'],
#   ['sugar wa'],
#   ['hilarious scene'],
#   ['banjo start']],
#  [['good hongkong'],
#   ['great stunt'],
#   ['dummy movement'],
#   ['occasional clutch'],
#   ['bite neck'],
#   ['genre movie'],
#   ['worth vote'],
#   ['til trilogy'],
#   ['first resident'],
#   ['evil dawn'],
#   ['dead remake']],
#  [['awful dylan'],
#   ['walsh script'],
#   ['primary school'],
#   ['visual effect'],
#   ['extensive use'],
#   ['single point'],
#   ['whole storyline'],
#   ['numerous clichés'],
#   ['eleniak nudity']],
#  [['small town'],
#   ['young son'],
#   ['pretentious film'],
#   ['unique vision'],
#   ['unmotivated answer']],
#  [['wa fortunate'],
#   ['enough catch'],
#   ['documentary hotdocs'],
#   ['shot period'],
#   ['palestinian child'],
#   ['personal life'],
#   ['terrorist monster'],
#   ['self indulgent'],
#   ['wing propaganda'],
#   ['political view']],
#  [['old clunker'],
#   ['american title'],
#   ['supernatural poe'],
#   ['main villain'],
#   ['much play'],
#   ['key heiress'],
#   ['unsavory character'],
#   ['familiar nowadays'],
#   ['real eye'],
#   ['countless time'],
#   ['scooby doo'],
#   ['secret panel'],
#   ['servant leslie'],
#   ['original man'],
#   ['complete goatee'],
#   ['accent kind'],
#   ['rare stuff'],
#   ['straight le'],
#   ['serious lady'],
#   ['excellent cast'],
#   ['lilli palmer'],
#   ['flair thing']],
#  [['good film'],
#   ['open mind'],
#   ['ridiculous ha'],
#   ['notice tv'],
#   ['obvious fish'],
#   ['niceness quietness'],
#   ['corporate business'],
#   ['top care'],
#   ['charismatic quality'],
#   ['half way'],
#   ['anagram coleman']],
#  [['able convince'],
#   ['good quality'],
#   ['exterior sorcha'],
#   ['bronte set'],
#   ['entire story'],
#   ['childhood year'],
#   ['interlude cousin'],
#   ['make sense'],
#   ['abbreviation wish'],
#   ['superior others'],
#   ['big screen'],
#   ['broadcast turn']],
#  [['great singer'],
#   ['much actor'],
#   ['flat luchini'],
#   ['pull audience'],
#   ['foreseeable screenplay'],
#   ['basic idea'],
#   ['want spend'],
#   ['laugh waste']],
#  [['real point'],
#   ['poor goat'],
#   ['crazy couple'],
#   ['many people'],
#   ['rightful place'],
#   ['gay transvestite']],
#  [['wealthy ray'],
#   ['dependable sam'],
#   ['early day'],
#   ['mae mercer'],
#   ['pre tv'],
#   ['hot pant']],
#  [['good way'],
#   ['important asset'],
#   ['main character'],
#   ['white movie'],
#   ['give audience'],
#   ['documentary time'],
#   ['old man'],
#   ['son grandson'],
#   ['excellent course'],
#   ['brilliant cast']],
#  [['russian quick'],
#   ['existential loneliness'],
#   ['characteristic psyche'],
#   ['key feature'],
#   ['excellent soundtrack'],
#   ['outstanding music'],
#   ['classical composer'],
#   ['piece praise'],
#   ['chopin prokofiev'],
#   ['alto mara'],
#   ['wonderful job'],
#   ['aleksandrov course'],
#   ['soviet director'],
#   ['interesting note'],
#   ['shaw arm'],
#   ['avent guarde'],
#   ['poet guadre'],
#   ['internal viewpoint'],
#   ['elegiac surprise'],
#   ['mainstream vision'],
#   ['overall get'],
#   ['worth effort']],
#  [['boldrini comment'],
#   ['long time'],
#   ['bad movie'],
#   ['good actress'],
#   ['speak example'],
#   ['irréversible likewise'],
#   ['surprised see'],
#   ['german actor'],
#   ['outstanding film'],
#   ['sorry director'],
#   ['humble spectator'],
#   ['possible rest']],
#  [['straight video'],
#   ['ha kinda'],
#   ['noreaga rapper'],
#   ['gold medallion'],
#   ['danny trejo'],
#   ['give choice'],
#   ['mexican border'],
#   ['start chick'],
#   ['hot death'],
#   ['awesome ask']],
#  [['first fdtd'], ['excellent movie'], ['special effect'], ['direct camera']],
#  [['top original'], ['good eddie'], ['noisy time'], ['third series']],
#  [['saw month'], ['real time'], ['welcome viewer']],
#  [['norma shearer'],
#   ['enough story'],
#   ['vivid character'],
#   ['sympathy predicament'],
#   ['sensitive portrayal'],
#   ['first feature'],
#   ['du barry'],
#   ['expert support'],
#   ['span w']],
#  [['different gangster'],
#   ['unique director'],
#   ['infamous driller'],
#   ['minute life'],
#   ['back dvd'],
#   ['good reason'],
#   ['walken harvey'],
#   ['scorsese style'],
#   ['black suit'],
#   ['glamarous rape'],
#   ['laugh friendship'],
#   ['legendary role'],
#   ['temperamental surprise'],
#   ['foolish johnny'],
#   ['michael corleone'],
#   ['angry man'],
#   ['emotional character'],
#   ['nice eddie'],
#   ['unbelievable camera'],
#   ['bucco soprano'],
#   ['rival bos'],
#   ['enough justice'],
#   ['typical violent'],
#   ['immune offense'],
#   ['innocent truck'],
#   ['pistol massacre'],
#   ['dark performance']],
#  [['iraq team'],
#   ['respective destination'],
#   ['funny film'],
#   ['michael pena'],
#   ['real story'],
#   ['optimistic pvt'],
#   ['southern sunshine'],
#   ['furious throw'],
#   ['robbery lash'],
#   ['good weapon'],
#   ['evangelical service'],
#   ['secret companion'],
#   ['key trudge'],
#   ['dealership luxury'],
#   ['dead family'],
#   ['colorful depiction'],
#   ['rich man'],
#   ['beautiful woman'],
#   ['umm start'],
#   ['many moment'],
#   ['tornado chance'],
#   ['delightful discovery'],
#   ['final thought']],
#  [['serial killer'], ['build finale'], ['fifteen minute'], ['edge seat']],
#  [['ok wa'],
#   ['satyajit ray'],
#   ['stellar debut'],
#   ['low budget'],
#   ['serious undertone'],
#   ['unconscious mind'],
#   ['capable actor'],
#   ['subtext end'],
#   ['young adult'],
#   ['novel addition'],
#   ['used literature'],
#   ['true strength'],
#   ['iconic actress'],
#   ['various place'],
#   ['give complement'],
#   ['particular darkly'],
#   ['ultimate villainess'],
#   ['female character'],
#   ['predict master']],
#  [['mary fact'],
#   ['shallow hal'],
#   ['decent story'],
#   ['classic wa'],
#   ['average comedy'],
#   ['original hook'],
#   ['siamese twin'],
#   ['excellent actor'],
#   ['obvious writer'],
#   ['standard cliché'],
#   ['rest shame']],
#  [['obscene reason'],
#   ['curious go'],
#   ['bride seed'],
#   ['silly death'],
#   ['porn horror']],
#  [['precious time'],
#   ['u deserve'],
#   ['fight equality'],
#   ['personal story'],
#   ['human peace']],
#  [['classic science'],
#   ['political thriller'],
#   ['catch year'],
#   ['widespread reputation'],
#   ['joseph sargent'],
#   ['cinematic career'],
#   ['worthy note'],
#   ['fine caper'],
#   ['amok theme'],
#   ['hal space'],
#   ['demon seed'],
#   ['triple bill'],
#   ['polished courtesy'],
#   ['shot westworld'],
#   ['imaginative setting'],
#   ['expert folmar'],
#   ['weird score'],
#   ['anonymous cast'],
#   ['intellect creation'],
#   ['apprehension future'],
#   ['dvd release'],
#   ['leap chance'],
#   ['able watch'],
#   ['scan version'],
#   ['widescreen composition'],
#   ['miraculous format']],
#  [['impossible movie'],
#   ['former hack'],
#   ['real drip'],
#   ['good guy'],
#   ['bad realize'],
#   ['see play'],
#   ['cocky eruope'],
#   ['right person'],
#   ['fresh project'],
#   ['phony confidence'],
#   ['give idiot'],
#   ['correct cloak'],
#   ['hard cry'],
#   ['impartial observer'],
#   ['meathead tripe'],
#   ['due expire'],
#   ['next month'],
#   ['young chick'],
#   ['boob hummer'],
#   ['wish join']],
#  [['good brutal'],
#   ['former thanks'],
#   ['social realism'],
#   ['bad guy'],
#   ['superficial layer'],
#   ['funny face'],
#   ['old actor'],
#   ['mean rest'],
#   ['poor try'],
#   ['give series']],
#  [['fair play'],
#   ['bad film'],
#   ['low script'],
#   ['insight psyche'],
#   ['kinky picture'],
#   ['main man'],
#   ['leather cap']],
#  [['cultural family'],
#   ['scorsese favorite'],
#   ['good look'],
#   ['ordinary guy'],
#   ['handsome crowd'],
#   ['early stage'],
#   ['rapport actor'],
#   ['many movie'],
#   ['hot catherine'],
#   ['first time'],
#   ['young frankenstein'],
#   ['untapped range'],
#   ['unused day'],
#   ['apparent feel'],
#   ['fit moment'],
#   ['second cheech'],
#   ['top meet'],
#   ['perennial weirdo'],
#   ['overlooked fascinating']],
#  [['resume movie'],
#   ['decent cast'],
#   ['unable anything'],
#   ['awful script'],
#   ['watch comedy'],
#   ['predictable story'],
#   ['unfunny course'],
#   ['write claire'],
#   ['amanda detmer'],
#   ['solid look'],
#   ['lovable loser'],
#   ['american pie'],
#   ['whiny pathetic'],
#   ['see video']],
#  [['pale comparison'],
#   ['hollywood wife'],
#   ['new generation'],
#   ['poor farrah'],
#   ['female lead'],
#   ['shallow nothing'],
#   ['interesting trash']],
#  [['great plot'],
#   ['good think'],
#   ['fair job'],
#   ['real problem'],
#   ['absolute perfection'],
#   ['exceptional performance']],
#  [['ray bradbury'],
#   ['martian chronicle'],
#   ['special lure'],
#   ['planetary astronomy'],
#   ['future space'],
#   ['last week'],
#   ['terrible series'],
#   ['cheap effect'],
#   ['bad plan'],
#   ['logical directing'],
#   ['x floor'],
#   ['second tape'],
#   ['first doubt'],
#   ['willing sit'],
#   ['original star'],
#   ['disagree appreciate']],
#  [['bravura performance'],
#   ['queen latifah'],
#   ['neglected thespian'],
#   ['torn attraction'],
#   ['marvelous father'],
#   ['personal demon'],
#   ['suzanne douglas'],
#   ['nicole carson'],
#   ['eddie griffin'],
#   ['exceptional story'],
#   ['uplifting love'],
#   ['enough make']],
#  [['tekkon kinkreet'],
#   ['visual anime'],
#   ['akira director'],
#   ['short genius'],
#   ['white older'],
#   ['tough violent'],
#   ['childish watch'],
#   ['evil developer'],
#   ['inner demon'],
#   ['giant robot'],
#   ['able fly'],
#   ['super power'],
#   ['fan cartoon']],
#  [['mexican movie'],
#   ['main issue'],
#   ['recognize people'],
#   ['decent film'],
#   ['great director'],
#   ['keep cine'],
#   ['many year'],
#   ['foreign audience'],
#   ['unfair lot'],
#   ['english p']],
#  [['bad wa'],
#   ['flat story'],
#   ['interesting way'],
#   ['click silver'],
#   ['poor movie'],
#   ['nic cage'],
#   ['christian slater'],
#   ['much talent'],
#   ['low budget']],
#  [['funny forget'],
#   ['start end'],
#   ['good mexico'],
#   ['mexican people'],
#   ['american boring']],
#  [['weird line'],
#   ['saturday afternoon'],
#   ['good budget'],
#   ['hard fan'],
#   ['evil manipulative'],
#   ['unlikeable person'],
#   ['awesome performance'],
#   ['richard jones'],
#   ['uncomfortable role'],
#   ['true love'],
#   ['married chip'],
#   ['steroid walk'],
#   ['dramatic scene'],
#   ['lauren son'],
#   ['great gatsby']],
#  ...]

# %%
from collections import Iterable
def nested_list_flatten(lis):
     for item in lis:
            if isinstance(item, Iterable) and not isinstance(item, str):
                for x in flatten(item):
                    yield x
            else:        
                    yield item

# %%
flat = list(nested_list_flatten(categoryList ))

# %%
counter=Counter(flat)
#most_commons = counter.most_common(10)
#most_commons
def freq_aspects(lst, k): 
    counted = Counter(lst) 
    #print(counted)  
    temp_lst = [] 
    for el in counted: 
        if counted[el] > k: 
            temp_lst.append(el) 
    return temp_lst

# %%
freq_feature = freq_aspects(flat,50)
freq_feature
# Out:
# ['top notch',
#  'great job',
#  'special effect',
#  'low budget',
#  'martial art',
#  'whole thing',
#  'big fan',
#  'real life',
#  'main character',
#  'first time',
#  'big screen',
#  'last year',
#  'many time',
#  'long time',
#  'saw movie',
#  'high school',
#  'bad movie',
#  'serial killer',
#  'good actor',
#  'young man',
#  'good job',
#  'cary grant',
#  'new york',
#  'many people',
#  'small town',
#  'subject matter',
#  'romantic comedy',
#  'young girl',
#  'good movie',
#  'great movie',
#  'true story',
#  'last night',
#  'good thing',
#  'bad guy',
#  'great film',
#  'good film',
#  'young woman',
#  'little bit']

# %%
#Adjective + Noun + Noun
def aspect_ANN(txt):
    
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    for line in sentList:
        new_txt_list = nltk.word_tokenize(line)
        taggedList = nltk.pos_tag(new_txt_list)

    #print(taggedList)
    categoryList = []

    for i in range(0,len(taggedList)-2):
        if((taggedList[i][1]=="JJ") and (taggedList[i+1][1]=="NN" or taggedList[i+1][1]=="NNS" or taggedList[i+1][1]=="NNP" or taggedList[i+1][1]=="NNPS") and 
          (taggedList[i+2][1]=="NN" or taggedList[i+2][1]=="NNS" or taggedList[i+2][1]=="NNP" or taggedList[i+2][1]=="NNPS")):

            categoryList.append([taggedList[i][0]+" " +taggedList[i+1][0]+" " +taggedList[i+2][0]])
        
    return categoryList

# %%
categoryList_ANN = [aspect_ANN(data1['unique_sent'][unt]) for unt in range(0,10000)]

# %%
flat_ANN = list(nested_list_flatten(categoryList_ANN))

# %%
freq_feature_ANN = freq_aspects(flat_ANN,10)
freq_feature_ANN
# Out:
# ['complete waste time',
#  'new york city',
#  'first time saw',
#  'low budget horror',
#  'low budget movie',
#  'local video store',
#  'low budget film']

# %%
#Adverb + Adjective
def aspect_AvA(txt):
    
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    for line in sentList:
        new_txt_list = nltk.word_tokenize(line)
        taggedList = nltk.pos_tag(new_txt_list)

    #print(taggedList)
    categoryList = []

    for i in range(0,len(taggedList)-2):
        if((taggedList[i][1]=="RB" or taggedList[i][1]=="RBR" or taggedList[i][1]=="RBS") and 
           (taggedList[i+1][1]=="JJ")):

            categoryList.append([taggedList[i][0]+" " +taggedList[i+1][0]])
        
    return categoryList

# %%
categoryList_AvA = [aspect_AvA(data1['unique_sent'][unt]) for unt in range(0,10000)]

# %%
flat_AvA = list(nested_list_flatten(categoryList_AvA))

# %%
freq_feature_AvA = freq_aspects(flat_AvA,50)
freq_feature_AvA
# Out:
# ['pretty much', 'pretty good', 'really good', 'really bad', 'quite good']

# %%
#Verb + Adjective + Noun
def aspect_VAN(txt):
    
   
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    for line in sentList:
        new_txt_list = nltk.word_tokenize(line)
        taggedList = nltk.pos_tag(new_txt_list)
    
    categoryList = []
    #VBD	verb, past tense	took
    #VBG	verb, gerund/present participle	taking
    #VBN	verb, past participle	taken
    #VBP	verb, sing. present, non-3d	take
    #VBZ	verb, 3rd person sing. present	takes
    #NN	noun, singular 'desk'
    #NNS	noun plural	'desks'
    #NNP	proper noun, singular	'Harrison'
    #NNPS	proper noun, plural	'Americans'
    for i in range(0,len(taggedList)-2):
        if((taggedList[i][1]=="VB" or taggedList[i][1]=="VBP" or taggedList[i][1]=="VBD" or taggedList[i][1]=="VBG" or taggedList[i][1]=="VBN") and taggedList[i+1][1]=="JJ" and (taggedList[i+2][1]=="NN" or taggedList[i+2][1]=="NNS" or taggedList[i+2][1]=="NNP" or taggedList[i+2][1]=="NNPS")):

            categoryList.append([taggedList[i][0]+" "+taggedList[i+1][0]+" "+taggedList[i+2][0]])

    return categoryList

# %%
categoryList_VAN = [aspect_VAN(data1['unique_sent'][unt]) for unt in range(0,10000)]

# %%
flat_VAN = list(nested_list_flatten(categoryList_VAN))

# %%
freq_feature_VAN = freq_aspects(flat_VAN,20)
freq_feature_VAN
# Out:
# ['seen long time', 'based true story']
