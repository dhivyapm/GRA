# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Labeled_dataset.csv',sep=',')
data_new = df.iloc[:10000]

# %%
dat = data_new.iloc[5001:10000]

# %%
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\divya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\divya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\divya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def text_2_emotions(text):
    result = te.get_emotion(text)
    return result

# %%
res = [text_2_emotions(data_new['unique_sent'][asp]) for asp in range(5001,10000)]

# %%
emo_data = pd.DataFrame()

# %%
emo_data['unique_sent'] = dat['unique_sent']

# %%
emo_data['all_emotions'] = res

# %%
emo_data.to_csv('movie_emotions_2.csv')

# %%
text = data_new['unique_sent'][7]
te.get_emotion(text)
# Out:
# {'Happy': 0.29, 'Angry': 0.07, 'Surprise': 0.29, 'Sad': 0.29, 'Fear': 0.07}

# %%
df['unique_sent'][7]
# Out:
# 'word  use  describe  movie  although  seen  hundred  time  get  past  andrew  knott  performance  must  admit  young  first  saw  huge  crush  dicken  wa  waiting  mary  fall  love  always  disappointed  end  anyways  think  outstanding  great  job  black  beauty  well  surprised  ha  extremely  successful'

# %%
df['Sentiment'][7]
# Out:
# 1

# %%
data_new.loc[:,('emotions')] = r
data_new.to_csv('movie_emo.csv',index=False)
# Out:
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:495: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   val = np.array(val, copy=False)
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %%
#data_new = df.iloc[:10000]
positive_data = data_new[data_new['Sentiment']==1]

# %%
r = []
for i in range(0,len(positive_data)):
    text = positive_data['unique_sent'].iloc[i]
    r.append(text_2_emotions(text))

# %%
positive_data.loc[:,('Emotions')] = r
# Out:
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:495: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   val = np.array(val, copy=False)
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %%
print(len(positive_data))
positive_data.to_csv('Positive_emo.csv',index=False)
# Out:
# 6103

# %%
neutral_data = data_new[data_new['Sentiment']==-1]

# %%
print(len(neutral_data))
# Out:
# 2170

# %%
r = []
for i in range(0,len(neutral_data)):
    text = neutral_data['unique_sent'].iloc[i]
    r.append(text_2_emotions(text))

# %%
neutral_data.loc[:,('Emotions')] = r
# Out:
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
neutral_data.to_csv('Neutral_emotions.csv',index=False)
# Out:
# 2170

# %%
neutral_data.Emotions.value_counts()
# Out:
# Fear        1277
# Surprise     464
# Sad          382
# Happy         43
# Angry          4
# Name: Emotions, dtype: int64

# %%
data_new = df.iloc[:10000]
negative_data = data_new[data_new['Sentiment']==0]

# %%
print(len(negative_data))
negative_data.Emotions.value_counts()
# Out:
# 1727
# Fear        768
# Sad         467
# Surprise    456
# Happy        27
# Angry         9
# Name: Emotions, dtype: int64

# %%
r = []
for i in range(0,len(negative_data)):
    text = negative_data['unique_sent'].iloc[i]
    r.append(text_2_emotions(text))

# %%
negative_data.loc[:,('Emotions')] = r
# Out:
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\divya\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
print(len(negative_data))
negative_data.to_csv('Negative_emotions.csv',index=False)
# Out:
# 1727

# %%
import pickle
file_name = "sample.pkl"
open_file = open(file_name, "rb")
loaded_list = pickle.load(open_file)
open_file.close()

print(loaded_list)
# Out:
# ['sometimes', 'review', 'pathetically', 'dumb', 'never', 'bad', 'else', 'hey', 'first', 'wa', 'cleverly', 'believe', 'wholly', 'nice', 'yet', 'lovely', 'scarcely', 'please', 'temperately', 'mention', 'nearly', 'whole', 'masterly', 'serious', 'elaborately', 'magical', 'initially', 'disappointed', 'honestly', 'combine', 'tilly', 'great', 'usually', 'combo', 'together', 'snoop', 'god', 'much', 'truly', 'awful', 'numbingly', 'dumb', 'still', 'able', 'really', 'decided', 'definitely', 'potential', 'genuinely', 'funny', 'even', 'overlap', 'deadly', 'thug', 'simply', 'know', 'swim', 'good', 'always', 'disappointed', 'well', 'surprised', 'extremely', 'successful', 'nearly', 'wept', 'yet', 'relax', 'really', 'wish', 'elite', 'hellcat', 'personally', 'attitude', 'sheppard', 'strudwick', 'mighty', 'unwelcome', 'still', 'unproven', 'sitcom', 'nanny', 'somewhat', 'annoying', 'long', 'straight', 'together', 'balcony', 'incredibly', 'cheesy', 'instead', 'real', 'mayhem', 'good', 'obviously', 'fat',
# ...
